# %%
import sys
import os
sys.path.append(os.path.realpath('../src'))

# %%
import bayes as b
trainingSet = "../data/lymph_train.arff"
testSet = "../data/lymph_test.arff"
b.data = b.readArff(trainingSet)
b.test_data = b.readTestArff(testSet)
b.tan()
# Out:
# lymphatics class
# block_of_affere extravasates class
# bl_of_lymph_c no_of_nodes_in class
# bl_of_lymph_s no_of_nodes_in class
# by_pass no_of_nodes_in class
# extravasates changes_in_stru class
# regeneration_of no_of_nodes_in class
# early_uptake_in no_of_nodes_in class
# lym_nodes_dimin no_of_nodes_in class
# lym_nodes_enlar no_of_nodes_in class
# changes_in_lym changes_in_stru class
# defect_in_node changes_in_node class
# changes_in_node changes_in_stru class
# changes_in_stru lymphatics class
# special_forms defect_in_node class
# dislocation_of no_of_nodes_in class
# exclusion_of_no changes_in_stru class
# no_of_nodes_in changes_in_stru class
#
# malign_lymph malign_lymph
# 0.9990207542696677
# malign_lymph malign_lymph
# 0.9975550363242903
# metastases malign_lymph
# 0.7136901186428650
# metastases malign_lymph
# 0.9657452477303995
# malign_lymph malign_lymph
# 0.7229537928378379
# malign_lymph malign_lymph
# 0.9831001048043397
# malign_lymph malign_lymph
# ...
